# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
energySaved = pd.read_csv("./data/energy_saved.csv")
waste_03_17 = pd.read_csv("./data/wastestats.csv")
waste_18_20 = pd.read_csv("./data/2018_2020_waste.csv")

# %%
waste_18_20.columns
# Out:
# Index(['Waste Type', 'Total Generated ('000 tonnes)',
#        'Total Recycled ('000 tonnes)', 'Year'],
#       dtype='object')

# %%
cleanedWaste_18_20 = waste_18_20.rename(
    columns={
        "Waste Type" : "waste_type",
        "Total Generated ('000 tonnes)" : "total_waste_generated_tonne",
        "Total Recycled ('000 tonnes)" : "total_waste_recycled_tonne",
        "Year" : "year"
    }
)

# %%
cleanedWaste_18_20.head(10)
# Out:
#                  waste_type  total_waste_generated_tonne  \
# 0  Construction& Demolition                         1624
# 1             Ferrous Metal                         1269
# 2           Paper/Cardboard                         1054
# 3                  Plastics                          949
# 4                      Food                          763
# 5                      Wood                          521
# 6             Horticultural                          320
# 7              Ash & Sludge                          240
# 8           Textile/Leather                          220
# 9                 Used Slag                          181
#
#    total_waste_recycled_tonne  year
# 0                        1618  2018
# 1                         126  2018
# 2                         586  2018
# 3                          41  2018
# 4                         126  2018
# 5                         428  2018
# 6                         227  2018
# 7                          25  2018
# 8                          14  2018
# 9                         179  2018

# %%
cleanedWaste_18_20['total_waste_generated_tonne'] = (cleanedWaste_18_20['total_waste_generated_tonne'] * 1000)

# %%
cleanedWaste_18_20['total_waste_recycled_tonne'] = (cleanedWaste_18_20['total_waste_recycled_tonne'] * 1000)

# %%
cleanedWaste_18_20["recycling_rate"] = round(cleanedWaste_18_20["total_waste_recycled_tonne"]/cleanedWaste_18_20["total_waste_generated_tonne"], 2)

# %%
cleanedWaste_18_20.head()
# Out:
#                  waste_type  total_waste_generated_tonne  \
# 0  Construction& Demolition                      1624000
# 1             Ferrous Metal                      1269000
# 2           Paper/Cardboard                      1054000
# 3                  Plastics                       949000
# 4                      Food                       763000
#
#    total_waste_recycled_tonne  year  recycling_rate
# 0                     1618000  2018            1.00
# 1                      126000  2018            0.10
# 2                      586000  2018            0.56
# 3                       41000  2018            0.04
# 4                      126000  2018            0.17

# %%
energySaved.head()
# Out:
#   The table gives the amount of energy saved in kilowatt hour (kWh) and the amount of crude oil (barrels) by recycling 1 metric tonne (1000 kilogram)  per waste type  \
# 0    1 barrel oil is approximately 159 litres of oil
# 1                                                NaN
# 2                                           material
# 3                                       energy_saved
# 4                                    crude_oil saved
#
#    Unnamed: 1    Unnamed: 2     Unnamed: 3         Unnamed: 4  Unnamed: 5
# 0         NaN           NaN            NaN                NaN         NaN
# 1         NaN           NaN            NaN                NaN         NaN
# 2     Plastic         Glass  Ferrous Metal  Non-Ferrous Metal       Paper
# 3    5774 Kwh        42 Kwh        642 Kwh          14000 Kwh    4100 kWh
# 4  16 barrels  0.12 barrels    1.8 barrels         40 barrels  11 barrels

# %%
energySaved = energySaved.T.iloc[1:, 2:].reset_index(drop=True).rename(
    columns={
        2:'materials',
        3:'energy_saved',
        4:'crudeOil_saved'
    }
)

# %%
energySaved.head()
# Out:
#            materials energy_saved crudeOil_saved
# 0            Plastic     5774 Kwh     16 barrels
# 1              Glass       42 Kwh   0.12 barrels
# 2      Ferrous Metal      642 Kwh    1.8 barrels
# 3  Non-Ferrous Metal    14000 Kwh     40 barrels
# 4              Paper     4100 kWh     11 barrels

# %%
waste_03_17.head()
# Out:
#             waste_type  waste_disposed_of_tonne  total_waste_recycled_tonne  \
# 0                 Food                   679900                    111100.0
# 1      Paper/Cardboard                   576000                    607100.0
# 2             Plastics                   762700                     59500.0
# 3                  C&D                     9700                   1585700.0
# 4  Horticultural waste                   111500                    209000.0
#
#    total_waste_generated_tonne  recycling_rate  year
# 0                       791000            0.14  2016
# 1                      1183100            0.51  2016
# 2                       822200            0.07  2016
# 3                      1595400            0.99  2016
# 4                       320500            0.65  2016

# %%
waste_03_17 = waste_03_17.loc[:,
    [
        "waste_type",
        "total_waste_generated_tonne",
        "total_waste_recycled_tonne",
        "recycling_rate",
        "year",
    ],
]

# %%
waste_03_17.head()
# Out:
#             waste_type  total_waste_generated_tonne  \
# 0                 Food                       791000
# 1      Paper/Cardboard                      1183100
# 2             Plastics                       822200
# 3                  C&D                      1595400
# 4  Horticultural waste                       320500
#
#    total_waste_recycled_tonne  recycling_rate  year
# 0                    111100.0            0.14  2016
# 1                    607100.0            0.51  2016
# 2                     59500.0            0.07  2016
# 3                   1585700.0            0.99  2016
# 4                    209000.0            0.65  2016

# %%
data = pd.concat([cleanedWaste_18_20, waste_03_17]).sort_values(by="year")
data.head()
# Out:
#       waste_type  total_waste_generated_tonne  total_waste_recycled_tonne  \
# 207  Scrap Tyres                        14400                      6200.0
# 209        Total                      4728200                   2223200.0
# 205        Glass                        65500                      6200.0
# 204       Sludge                        88500                         0.0
# 203    Used Slag                       260300                    238500.0
#
#      year  recycling_rate
# 207  2003            0.43
# 209  2003            0.47
# 205  2003            0.09
# 204  2003            0.00
# 203  2003            0.92

# %%
overall = data[(data["waste_type"] == "Overall") | (data["waste_type"] == "Total")]

# %%
fig = go.Figure()

# %%
fig.add_trace(
    go.Bar(
        x = overall['year'],
        y = overall["total_waste_generated_tonne"],
        name = "Waste Generated",

    )
)

fig.add_trace(
    go.Bar(
        x = overall['year'],
        y = overall["total_waste_recycled_tonne"],
        name = "Waste Recycled",

    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fe9cf776-cb3e-46a4-8d82-64e6ffc550b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe9cf776-cb3e-46a4-8d82-64e6ffc550b2")) {                    Plotly.newPlot(                        "fe9cf776-cb3e-46a4-8d82-64e6ffc550b2",                        [{"name":"Waste Generated","x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":[4728200,4789700,5018200,5220500,5600800,5970200,6114100,6517000,6898300,7269500,7851500,7514500,7673500,7814200,7704300,7695000,7234000,5880000],"type":"bar"},{"name":"Waste Recycled","x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":[2223200.0,2307100.0,2469400.0,2656900.0,3034800.0,3342600.0,3485200.0,3757500.0,4038800.0,4335600.0,4825900.0,4471100.0,4649700.0,4769000.0,4724300.0,4726000.0,4247000.0,3040000.0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"e ...

# %%
data["waste_type"].value_counts()
# Out:
# waste_type
# Glass                                      18
# Paper/Cardboard                            18
# Textile/Leather                            18
# Plastics                                   17
# Total                                      15
# Scrap Tyres                                13
# Used Slag                                  13
# Others (stones, ceramics & rubber etc)     12
# Sludge                                     11
# Non-ferrous Metals                         11
# Horticultural Waste                        11
# Construction Debris                        11
# Food waste                                 11
# Wood/Timber                                11
# Ferrous Metal                               9
# Food                                        7
# Wood                                        7
# Ferrous metal                               5
# Used slag                                   5
# Ash & Sludge                                5
# Scrap tyres                                 5
# Horticultural waste                         4
# Ferrous Metals                              4
# Non-ferrous metal                           4
# C&D                                         3
# Horticultural                               3
# Overall                                     3
# Others (stones, ceramic, rubber, ect)       2
# Construction& Demolition                    2
# Non-Ferrous Metal                           2
# Others                                      1
# Construction & Demolition                   1
# Others (stones, ceramics, etc.)             1
# Non-ferrous metals                          1
# Others (stones, ceramic, rubber, etc.)      1
# Plastic                                     1
# Ash and sludge                              1
# Construction debris                         1
# Others (stones, ceramics & rubber etc.)     1
# Ash & sludge                                1
# Name: count, dtype: int64

# %%
data["waste_type"] = data["waste_type"].str.replace(
    "Non-ferrous metal", "Non-Ferrous Metal"
    )
data["waste_type"] = data["waste_type"].str.replace(
    "Non-ferrous metals", "Non-Ferrous Metal"
    )
data["waste_type"] = data["waste_type"].str.replace(
    "Non-Ferrous Metals", "Non-Ferrous Metal"
    )
data["waste_type"] = data["waste_type"].str.replace(
    "Plastics", "Plastic"
    )
data["waste_type"] = data["waste_type"].str.replace(
    "Ferrous metal", "Ferrous Metal"
    )
data["waste_type"] = data["waste_type"].str.replace(
    "Paper/Cardboard", "Paper"
    )

# %%
total_data = data.merge(
    energySaved, how='left', left_on='waste_type', right_on='materials'
).dropna()

# %%
total_data.head()
# Out:
#    waste_type  total_waste_generated_tonne  total_waste_recycled_tonne  year  \
# 2       Glass                        65500                      6200.0  2003
# 10    Plastic                       579900                     39100.0  2003
# 11      Paper                      1084700                    466200.0  2003
# 25    Plastic                       683100                     74100.0  2004
# 26      Paper                      1132100                    519900.0  2004
#
#     recycling_rate materials energy_saved crudeOil_saved
# 2             0.09     Glass       42 Kwh   0.12 barrels
# 10            0.07   Plastic     5774 Kwh     16 barrels
# 11            0.43     Paper     4100 kWh     11 barrels
# 25            0.11   Plastic     5774 Kwh     16 barrels
# 26            0.46     Paper     4100 kWh     11 barrels

# %%
total_data["energy_saved"] = total_data.loc[:, "energy_saved"].str.replace("kWh", "")
total_data.head()
# Out:
#    waste_type  total_waste_generated_tonne  total_waste_recycled_tonne  year  \
# 2       Glass                        65500                      6200.0  2003
# 10    Plastic                       579900                     39100.0  2003
# 11      Paper                      1084700                    466200.0  2003
# 25    Plastic                       683100                     74100.0  2004
# 26      Paper                      1132100                    519900.0  2004
#
#     recycling_rate materials energy_saved crudeOil_saved
# 2             0.09     Glass       42 Kwh   0.12 barrels
# 10            0.07   Plastic     5774 Kwh     16 barrels
# 11            0.43     Paper        4100      11 barrels
# 25            0.11   Plastic     5774 Kwh     16 barrels
# 26            0.46     Paper        4100      11 barrels

# %%
total_data["energy_saved"] = (total_data.loc[:, "energy_saved"].str.replace("Kwh", "").astype(int))
total_data.head()
# Out:
#    waste_type  total_waste_generated_tonne  total_waste_recycled_tonne  year  \
# 2       Glass                        65500                      6200.0  2003
# 10    Plastic                       579900                     39100.0  2003
# 11      Paper                      1084700                    466200.0  2003
# 25    Plastic                       683100                     74100.0  2004
# 26      Paper                      1132100                    519900.0  2004
#
#     recycling_rate materials  energy_saved crudeOil_saved
# 2             0.09     Glass            42   0.12 barrels
# 10            0.07   Plastic          5774     16 barrels
# 11            0.43     Paper          4100     11 barrels
# 25            0.11   Plastic          5774     16 barrels
# 26            0.46     Paper          4100     11 barrels

# %%
total_data["total_energy_saved"] = (total_data.loc[:, "total_waste_recycled_tonne"] * total_data.loc[:, "energy_saved"])

# %%
total_data["crudeOil_saved"] = total_data.loc[:, "crudeOil_saved"].str.replace("barrels", "")
total_data["crudeOil_saved"] = total_data.loc[:, "crudeOil_saved"].str.replace("barrels", "").astype(float)

# %%
total_data.head()
# Out:
#    waste_type  total_waste_generated_tonne  total_waste_recycled_tonne  year  \
# 2       Glass                        65500                      6200.0  2003
# 10    Plastic                       579900                     39100.0  2003
# 11      Paper                      1084700                    466200.0  2003
# 25    Plastic                       683100                     74100.0  2004
# 26      Paper                      1132100                    519900.0  2004
#
#     recycling_rate materials  energy_saved  crudeOil_saved  total_energy_saved
# 2             0.09     Glass            42            0.12        2.604000e+05
# 10            0.07   Plastic          5774           16.00        2.257634e+08
# 11            0.43     Paper          4100           11.00        1.911420e+09
# 25            0.11   Plastic          5774           16.00        4.278534e+08
# 26            0.46     Paper          4100           11.00        2.131590e+09

# %%
total_data["waste_type"].unique()
# Out:
# array(['Glass', 'Plastic', 'Paper', 'Ferrous Metal', 'Non-Ferrous Metal'],
#       dtype=object)

# %%
total_data.drop(columns=["materials"], axis=1, inplace=True)

# %%
print(total_data.dtypes)
# Out:
# waste_type                      object
# total_waste_generated_tonne      int64
# total_waste_recycled_tonne     float64
# year                             int64
# recycling_rate                 float64
# energy_saved                     int64
# crudeOil_saved                 float64
# total_energy_saved             float64
# dtype: object

# %%
total_data.groupby(by=["waste_type"]).mean()[
    "recycling_rate"
    ].to_frame().style.\
    background_gradient(cmap="Pastel1_r", subset=["recycling_rate"])
# Out:
# <style type="text/css">
# #T_72444_row0_col0, #T_72444_row2_col0 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# #T_72444_row1_col0, #T_72444_row4_col0 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_72444_row3_col0 {
#   background-color: #fed9a6;
#   color: #000000;
# }
# </style>
# <table id="T_72444" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72444_level0_col0" class="col_heading level0 col0" >recycling_rate</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >waste_type</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72444_level0_row0" class="row_heading level0 row0" >Ferrous Metal</th>
#       <td id="T_72444_row0_col0" class="data row0 col0" >0.900714</td>
#     </tr>
#     <tr>
#       <th id="T_72444_level0_row1" class="row_heading level0 row1" >Glass</th>
#       <td id="T_72444_row1_col0" class="data row1 col0" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_72444_level0_row2" class="row_heading level0 row2" >Non-Ferrous Metal</th>
#       <td id="T_72444_row2_col0" class="data row2 col0" >0.942857</td>
#     </tr>
#     <tr>
#       <th id="T_72444_level0_row3" class="row_heading level0 row3" >Paper</th>
#       <td id="T_72444_row3_col0" class="data row3 col0" >0.498333</td>
#     </tr>
#     <tr>
#       <th id="T_72444_level0_row4" class="row_heading level0 row4" >Plastic</th>
#       <td id="T_72444_row4_col0" class="data row4 col0" >0.086667</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.box(total_data, x='year', y='total_waste_recycled_tonne')
fig.update_traces(quartilemethod="exclusive")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a03b901c-9ba7-4796-b08e-ffed50faf371" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a03b901c-9ba7-4796-b08e-ffed50faf371")) {                    Plotly.newPlot(                        "a03b901c-9ba7-4796-b08e-ffed50faf371",                        [{"alignmentgroup":"True","hovertemplate":"year=%{x}\u003cbr\u003etotal_waste_recycled_tonne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":[2003,2003,2003,2004,2004,2004,2005,2005,2005,2006,2006,2006,2007,2007,2007,2007,2008,2008,2008,2008,2009,2009,2009,2009,2010,2010,2010,2010,2011,2011,2011,2011,2012,2012,2012,2012,2013,2013,2013,2013,2014,2014,2014,2014,2014,2015,2015,2015,2015,2015,2016,2016,2016,2016,2016,2017,2017,2017,2017,2017,2018,2018,2018,2018,2018,2019,2019,2019,2019,2019,2020,2020,2020,2020,2020],"x0":" ","xaxis":"x","y":[6200.0,39100.0,466200.0,74100.0,519900.0,4900.0,3800.0,540500.0,86000.0,77800.0,571400.0,6400.0,619000.0,75000.0,668000.0,5800.0,608600.0,61200.0,10000.0,735000.0,574200.0,60300.0,806200.0,15600.0,738200.0,78100.0,1127500.0,19200.0,21400.0,77000.0,765000.0,1171600.0,696700.0,82100.0,1331200.0,19500.0,679400.0,91100.0,1369200.0,14600.0,646500.0,1388900.0,80000.0,15700.0,94700.0,603700.0,57800.0,14600.0,160400.0,1333300.0,607100.0,59500.0,1351500.0,95900.0,14700.0,1371000.0,92200.0,568800.0,12400.0,51800.0,170000.0,41000.0,586000.0,126000.0,12000.0,1270000.0,449000.0,37000.0,124000.0,11000.0,7000.0,73000.0,36000.0,930000.0,432000.0],"y0":" ","yaxis":"y","type":"box","quartilemethod":"exclusive"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0 ...

# %%
total_data.loc[237, "total_waste_recycled_tonne"] = 1260000
total_data["total_energy_saved"] = total_data.loc[:, "total_waste_recycled_tonne"] * (
    total_data.loc[:, "energy_saved"]
)

fig = px.box(total_data, x="year", y="total_waste_recycled_tonne")
fig.update_traces(quartilemethod="exclusive")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a46c6d88-e3b2-4022-ba40-fc4979cdeb79" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a46c6d88-e3b2-4022-ba40-fc4979cdeb79")) {                    Plotly.newPlot(                        "a46c6d88-e3b2-4022-ba40-fc4979cdeb79",                        [{"alignmentgroup":"True","hovertemplate":"year=%{x}\u003cbr\u003etotal_waste_recycled_tonne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":[2003,2003,2003,2004,2004,2004,2005,2005,2005,2006,2006,2006,2007,2007,2007,2007,2008,2008,2008,2008,2009,2009,2009,2009,2010,2010,2010,2010,2011,2011,2011,2011,2012,2012,2012,2012,2013,2013,2013,2013,2014,2014,2014,2014,2014,2015,2015,2015,2015,2015,2016,2016,2016,2016,2016,2017,2017,2017,2017,2017,2018,2018,2018,2018,2018,2019,2019,2019,2019,2019,2020,2020,2020,2020,2020],"x0":" ","xaxis":"x","y":[6200.0,39100.0,466200.0,74100.0,519900.0,4900.0,3800.0,540500.0,86000.0,77800.0,571400.0,6400.0,619000.0,75000.0,668000.0,5800.0,608600.0,61200.0,10000.0,735000.0,574200.0,60300.0,806200.0,15600.0,738200.0,78100.0,1127500.0,19200.0,21400.0,77000.0,765000.0,1171600.0,696700.0,82100.0,1331200.0,19500.0,679400.0,91100.0,1369200.0,14600.0,646500.0,1388900.0,80000.0,15700.0,94700.0,603700.0,57800.0,14600.0,160400.0,1333300.0,607100.0,59500.0,1351500.0,95900.0,14700.0,1371000.0,92200.0,568800.0,12400.0,51800.0,170000.0,41000.0,586000.0,1260000.0,12000.0,1270000.0,449000.0,37000.0,124000.0,11000.0,7000.0,73000.0,36000.0,930000.0,432000.0],"y0":" ","yaxis":"y","type":"box","quartilemethod":"exclusive"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1. ...

# %%
fig = px.box(total_data, x="year", y="total_energy_saved")
fig.update_traces(quartilemethod="exclusive")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a7f21221-76a4-4a31-ad77-02fa4cb87f00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7f21221-76a4-4a31-ad77-02fa4cb87f00")) {                    Plotly.newPlot(                        "a7f21221-76a4-4a31-ad77-02fa4cb87f00",                        [{"alignmentgroup":"True","hovertemplate":"year=%{x}\u003cbr\u003etotal_energy_saved=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":[2003,2003,2003,2004,2004,2004,2005,2005,2005,2006,2006,2006,2007,2007,2007,2007,2008,2008,2008,2008,2009,2009,2009,2009,2010,2010,2010,2010,2011,2011,2011,2011,2012,2012,2012,2012,2013,2013,2013,2013,2014,2014,2014,2014,2014,2015,2015,2015,2015,2015,2016,2016,2016,2016,2016,2017,2017,2017,2017,2017,2018,2018,2018,2018,2018,2019,2019,2019,2019,2019,2020,2020,2020,2020,2020],"x0":" ","xaxis":"x","y":[260400.0,225763400.0,1911420000.0,427853400.0,2131590000.0,205800.0,159600.0,2216050000.0,496564000.0,449217200.0,2342740000.0,268800.0,2537900000.0,433050000.0,428856000.0,243600.0,2495260000.0,353368800.0,420000.0,471870000.0,2354220000.0,348172200.0,517580400.0,655200.0,3026620000.0,450949400.0,723855000.0,806400.0,898800.0,444598000.0,3136500000.0,752167200.0,2856470000.0,474045400.0,854630400.0,819000.0,2785540000.0,526011400.0,879026400.0,613200.0,2650650000.0,891673800.0,461920000.0,659400.0,1325800000.0,2475170000.0,333737200.0,613200.0,2245600000.0,855978600.0,2489110000.0,343553000.0,867663000.0,1342600000.0,617400.0,880182000.0,1290800000.0,2332080000.0,520800.0,299093200.0,2380000000.0,236734000.0,2402600000.0,808920000.0,504000.0,815340000.0,1840900000.0,213638000.0,1736000000.0,462000.0,294000.0,1022000000.0,207864000.0,597060000.0,1771200000.0],"y0":" ","yaxis":"y","type":"box","quartilemethod":"exclusive"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039 ...

# %%
fig = px.scatter(
    total_data,
    x="year",
    y="total_energy_saved",
    size="total_waste_recycled_tonne",
    color="waste_type",
    size_max=50,
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2a326367-8c93-483c-884e-711a38716fe4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a326367-8c93-483c-884e-711a38716fe4")) {                    Plotly.newPlot(                        "2a326367-8c93-483c-884e-711a38716fe4",                        [{"hovertemplate":"waste_type=Glass\u003cbr\u003eyear=%{x}\u003cbr\u003etotal_energy_saved=%{y}\u003cbr\u003etotal_waste_recycled_tonne=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Glass","marker":{"color":"#636efa","size":[6200.0,4900.0,3800.0,6400.0,5800.0,10000.0,15600.0,19200.0,21400.0,19500.0,14600.0,15700.0,14600.0,14700.0,12400.0,12000.0,11000.0,7000.0],"sizemode":"area","sizeref":555.56,"symbol":"circle"},"mode":"markers","name":"Glass","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[260400.0,205800.0,159600.0,268800.0,243600.0,420000.0,655200.0,806400.0,898800.0,819000.0,613200.0,659400.0,613200.0,617400.0,520800.0,504000.0,462000.0,294000.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"waste_type=Plastic\u003cbr\u003eyear=%{x}\u003cbr\u003etotal_energy_saved=%{y}\u003cbr\u003etotal_waste_recycled_tonne=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Plastic","marker":{"color":"#EF553B","size":[39100.0,74100.0,86000.0,77800.0,75000.0,61200.0,60300.0,78100.0,77000.0,82100.0,91100.0,80000.0,57800.0,59500.0,51800.0,41000.0,37000.0,36000.0],"sizemode":"area","sizeref":555.56,"symbol":"circle"},"mode":"markers","name":"Plastic","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[225763400.0,427853400.0,496564000.0,449217200.0,433050000.0,353368800.0,348172200.0,450949400.0,444598000.0,474045400.0,526011400.0,461920000.0,333737200.0,343553000.0,299093200.0,236734000.0,213638000.0,207864000.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"waste_type=Paper\u003cbr\u003eyear=%{x}\u003cbr\u003etotal_energy_saved=%{y}\u003cbr\u003etotal_waste_recycled_tonne=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Paper","marker":{"color":"#00cc96","size":[466200.0,519900.0,540500.0,571400.0,619000.0,608600.0,574200.0,738200.0,765000.0,696700.0,679400.0,646500.0,603700.0,607100.0,568800.0,586000.0,449000.0,432000.0],"sizemode":"area","sizeref":555.56,"symbol":"circle"},"mode":"markers","name":"Paper","orientation":"v","showlegend":true,"x":[2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[1911420000.0,2131590000.0,2216050000.0,2342740000.0,2537900000.0,2495260000.0,2354220000.0,3026620000.0,3136500000.0,2856470000.0,2785540000.0,2650650000.0,2475170000.0,2489110000.0,2332080000.0,2402600000.0,1840900000.0,1771200000.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"waste_type=Ferrous Metal\u003cbr\u003eyear=%{x}\u003cbr\u003etotal_energy_saved=%{y}\u003cbr\u003etotal_waste_recycled_tonne=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ferrous Metal","marker":{"color":"#ab63fa","size":[668000.0,735000.0,806200.0,1127500.0,1171600.0,1331200.0,1369200.0,1388900.0,1333300.0,1351500.0,1371000.0,1260000.0,1270000.0,930000.0],"sizemode":"area","sizeref":555.56,"symbol":"circle"},"mode":"markers","name":"Ferrous Metal","orientation":"v","showlegend":true,"x":[2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[428856000.0,471870000.0,517580400.0,723855000.0,752167200.0,854630400.0,879026400.0,891673800.0,855978600.0,867663000.0,880182000.0,808920000.0,815340000.0,597060000.0],"yaxis":"y","type":"scatter"},{" ...

# %%
annual_energy_savings = pd.DataFrame(
    total_data.groupby(by=["year"]).sum()["total_energy_saved"],
    columns=["total_energy_saved"],
    ).astype({"total_energy_saved": int})

# %%
annual_energy_savings["total_energy_saved"] = (
    round(annual_energy_savings["total_energy_saved"] / 1000000, 2)\
    .astype(str) + " GWh"
)
annual_energy_savings.tail()
# Out:
#      total_energy_saved
# year
# 2016        5043.54 GWh
# 2017        4802.68 GWh
# 2018        5828.76 GWh
# 2019        4606.34 GWh
# 2020        3598.42 GWh
